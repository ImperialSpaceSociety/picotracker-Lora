# %%
import json
import re
from pathlib import Path
import traceback




def read_file(filename):
    f = open(filename, 'r')
    return f.read()

def parse_older_format(data_str)->list:    
    line_selector = r"([0-9]{4})-(0[1-9]|1[0-2])-(0[1-9]|[1-2][0-9]|3[0-1]) (2[0-3]|[01][0-9]):([0-5][0-9]):([0-5][0-9]),([0-9]{3}) (.*) b'(.*)'"
    strings = re.findall(line_selector,data_str)
    data_list = []
    for i in strings:
        year, month, day, hour, minute, second, ms, importance, data = i
        d = json.loads(data)
        data_list.append(d)
    return data_list

def parse_newer_format(data_str)->list:    
    line_selector = r"\[(Sun|Mon|Tues|Wed|Thu|Fri|Sat), (\d{2}) (Jan|Feb|Mar|Apr|May|June|July|Aug|Sep|Oct|Nov|Dec) (\d{4}) (\d{2}):(\d{2}):(\d{2})\] INFO b'(.*)'"
    strings = re.findall(line_selector,data_str)
    data_list = []
    for i in strings:
        day, date, month, year, hour, minute, second, data = i
        d = json.loads(data)
        data_list.append(d)
    return data_list


def parse_ttn_log_format(data_str)->list:    
    line_selector = r"([0-9]{4})-(0[1-9]|1[0-2])-(0[1-9]|[1-2][0-9]|3[0-1]) (2[0-3]|[01][0-9]):([0-5][0-9]):([0-5][0-9]),([0-9]{3}) INFO  TtnListener:\d+ - Message arrived on topic 'icss_lora_tracker/devices/icspace19/up': ({.*})"
    strings = re.findall(line_selector,data_str)
    data_list = []
    for i in strings:
        year, month, day, hour, minute, second, ms, data = i
        d = json.loads(data)
        data_list.append(d)
    return data_list


def special_replace(raw_str,the_string):
    return raw_str.replace("{}:".format(the_string),'"{}":'.format(the_string))

def process_str(string):
    raw_str = string.replace("MSG","").replace("(","{").replace(")","}").replace("=",":").replace("'",'"')
    things_to_replace = ["app_id","dev_id","hardware_serial","counter","payload_raw","payload_fields",
                         "metadata","frequency","modulation","data_rate","airtime","coding_rate",
                        "gtw_id","gtw_trusted","channel","rssi","snr","rf_chain","latitude","longitude",
                         "location_source","analog_in_3","barometric_pressure_0","digital_out_4","gps_2",
                         "temperature_1","altitude","is_retry","antenna"]

    for i in things_to_replace:

        raw_str = raw_str.replace("{}".format(i),'"{}"'.format(i))

    raw_str = raw_str.replace("{time",'{"time"')
    raw_str = raw_str.replace("True",'true')
    raw_str = raw_str.replace("time:",'"time":')
    raw_str = raw_str.replace("fine_timestamp:",'"fine_timestamp":')
    raw_str = raw_str.replace("fine_timestamp_encrypted:",'"fine_timestamp_encrypted":')
    raw_str = raw_str.replace("timestamp:",'"timestamp":')
    raw_str = special_replace(raw_str,"port")
    raw_str = special_replace(raw_str,"gateways")

    return raw_str

def parse_jackson_log_format(data_str)->list:    
    line_selector = r"(MSG\(app_id='icss_lora_tracker', dev_id='icspace.*)"
    strings = re.findall(line_selector,data_str)
    data_list = []
    for i in strings:
        data = i
        data = process_str(data)
        if "relative_humidity_2" in data:
            continue
        if "analog_in_1" in data:
            continue

        try:
            d = json.loads(data)
        except Exception:
            print(traceback.format_exc())
            print(data)

        data_list.append(d)
    return data_list

# %%
filename = "mqtt_log_data-1.txt"
str_data= read_file(filename)
data_new = parse_newer_format(str_data)

# %%
icspace23_list = []
for i in data_new:
    dev_id = i.get('dev_id', None)
    if dev_id == "icspace23":
        icspace23_list.append(i)

# %%
import base64
import json
from datetime import datetime
from datetime import timezone


class PacketParser:
    def __init__(self, raw_packet):
        self.raw_packet = raw_packet
        self.current_long = 0
        self.current_lat = 0
        self.current_alt = 0
        self.current_time = 0
        self.num_sats = 0
        self.days_of_playback = 0
        self.noloadVoltage = 0
        self.loadVoltage = 0
        self.pressure = 0
        self.reset_cnt = 0
        self.boardTemp = 0
        self.device_id = ""
        self.past_positions =[]

    def parse_packet(self):
        payload_json = self.raw_packet

        date_time_str = payload_json["metadata"]["time"][:-4]
        self.current_time = datetime.strptime(date_time_str, '%Y-%m-%dT%H:%M:%S.%f')
        self.current_time = self.current_time.replace(tzinfo=timezone.utc)

        self.device_id = payload_json["dev_id"]


        raw_payload = payload_json["payload_raw"]

        if raw_payload == None:
            raise ValueError("No payload found")

        try:
            self.parse_raw_payload(raw_payload,self.current_time)
        except Exception as ex:
            print(ex)
        
    def parse_raw_payload(self,raw_payload,current_time):

        hex_payload = base64.b64decode(raw_payload)

        self.pressure = ((hex_payload[2] >> 1) & 0b01111111) * 10
        self.reset_cnt = hex_payload[3] & 0b00000111
        self.boardTemp = int.from_bytes(hex_payload[4:5], byteorder="little", signed=True)
        self.noloadVoltage = ((hex_payload[0] >> 3) & 0b00011111) + 18
        self.loadVoltage = (((hex_payload[0] << 2) & 0b00011100) | ((hex_payload[1] >> 6) & 0b00000011)) + 18
        self.days_of_playback = hex_payload[1] & 0b00111111
        self.num_sats = hex_payload[3] >> 3 & 0b00011111
        self.current_long = int.from_bytes(hex_payload[7:9], byteorder="little", signed=True) * 0xffff / 1e7
        self.current_lat = int.from_bytes(hex_payload[5:7], byteorder="little", signed=True) * 0xffff / 1e7
        self.current_alt = int(int.from_bytes(hex_payload[9:11], byteorder="little", signed=False) * 0xff / 1000)

        
        self.past_positions = []
        for i in range(12):
            offset = (i+1) * 9
            current_long = int.from_bytes(hex_payload[13+offset:15+offset], byteorder="little", signed=True) * 0xffff / 1e7
            current_lat = int.from_bytes(hex_payload[11+offset:13+offset], byteorder="little", signed=True) * 0xffff / 1e7
            current_alt = int(int.from_bytes(hex_payload[15+offset:17+offset], byteorder="little", signed=False) * 0xff / 1000)
            time = datetime.fromtimestamp(1577840461 + int.from_bytes(hex_payload[17+offset:20+offset], byteorder="little", signed=False) * 60)
            
            past_pos = {
                "altitude":current_alt,
                "latitude":current_lat,
                "longitude":current_long,
                "time_stamp":time

            }
            
            self.past_positions.append(past_pos)

# %%
for tx in icspace23_list:
    parsed_packet = PacketParser(tx)
    try:
        parsed_packet.parse_packet()
        
        payload_fields = {"barometric_pressure_0":parsed_packet.pressure,
                          "digital_out_4":parsed_packet.num_sats,
                          "gps_2":{"altitude":parsed_packet.current_alt,"latitude":parsed_packet.current_lat,"longitude":parsed_packet.current_long},
                          "temperature_1":parsed_packet.boardTemp
                          }
        print(payload_fields)
        tx["payload_fields"] = payload_fields
        
        for past_pos in parsed_packet.past_positions:
            new_pos = {
                "app_id":"icss_lora_tracker",
                "dev_id": "icspace23",
                "payload_fields":{"gps_2":{
                    "altitude":past_pos["altitude"],
                    "latitude":past_pos["latitude"],
                    "longitude":past_pos["longitude"]
                }},
                "metadata":{"time":past_pos["time_stamp"].isoformat() + 'Z'}
            }
            icspace23_list.append(new_pos)
    except:
        pass
# Out:
# {'barometric_pressure_0': 880, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 13}
# {'barometric_pressure_0': 880, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 13}
# {'barometric_pressure_0': 920, 'digital_out_4': 4, 'gps_2': {'altitude': 875, 'latitude': 52.008576, 'longitude': 1.5400725}, 'temperature_1': 13}
# {'barometric_pressure_0': 200, 'digital_out_4': 11, 'gps_2': {'altitude': 10538, 'latitude': 51.8709525, 'longitude': 4.089384}, 'temperature_1': -29}
# {'barometric_pressure_0': 200, 'digital_out_4': 11, 'gps_2': {'altitude': 10538, 'latitude': 51.8709525, 'longitude': 4.089384}, 'temperature_1': -29}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10785, 'latitude': 51.877506, 'longitude': 4.272882}, 'temperature_1': -26}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10785, 'latitude': 51.877506, 'longitude': 4.272882}, 'temperature_1': -26}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10785, 'latitude': 51.877506, 'longitude': 4.272882}, 'temperature_1': -26}
# {'barometric_pressure_0': 0, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 2}
# {'barometric_pressure_0': 0, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 2}
# {'barometric_pressure_0': 0, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 2}
# {'barometric_pressure_0': 0, 'digital_out_4': 0, 'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0}, 'temperature_1': 2}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10657, 'latitude': 53.450346, 'longitude': 22.8782685}, 'temperature_1': -24}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10660, 'latitude': 53.489667, 'longitude': 23.042106}, 'temperature_1': -19}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10660, 'latitude': 53.489667, 'longitude': 23.042106}, 'temperature_1': -19}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10669, 'latitude': 53.5093275, 'longitude': 23.107641}, 'temperature_1': -19}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10661, 'latitude': 53.5224345, 'longitude': 23.1666225}, 'temperature_1': -20}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10661, 'latitude': 53.5224345, 'longitude': 23.1666225}, 'temperature_1': -20}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10656, 'latitude': 53.5617555, 'longitude': 23.343567}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10656, 'latitude': 53.5617555, 'longitude': 23.343567}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10661, 'latitude': 53.568309, 'longitude': 23.356674}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10661, 'latitude': 53.568309, 'longitude': 23.356674}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10655, 'latitude': 53.5879695, 'longitude': 23.4287625}, 'temperature_1': -15}
# {'barometric_pressure_0': 220, 'digital_out_4': 9, 'gps_2': {'altitude': 10657, 'latitude': 53.5879695, 'longitude': 23.4418695}, 'temperature_1': -17}
# {'barometric_pressure_0': 220, 'digital_out_4': 9, 'gps_2': {'altitude': 10657, 'latitude': 53.5879695, 'longitude': 23.4418695}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10634, 'latitude': 53.6010765, 'longitude': 23.4942975}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10634, 'latitude': 53.6010765, 'longitude': 23.4942975}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10634, 'latitude': 53.6010765, 'longitude': 23.4942975}, 'temperature_1': -14}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10662, 'latitude': 53.673165, 'longitude': 23.802312}, 'temperature_1': -15}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10662, 'latitude': 53.673165, 'longitude': 23.802312}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10641, 'latitude': 53.686272, 'longitude': 23.8350795}, 'temperature_1': -9}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10641, 'latitude': 53.686272, 'longitude': 23.8350795}, 'temperature_1': -9}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10666, 'latitude': 53.7583605, 'longitude': 24.1365405}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10666, 'latitude': 53.7583605, 'longitude': 24.1365405}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10664, 'latitude': 53.7583605, 'longitude': 24.1496475}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10664, 'latitude': 53.7583605, 'longitude': 24.1496475}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10660, 'latitude': 53.7583605, 'longitude': 24.1627545}, 'temperature_1': -20}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10660, 'latitude': 53.7583605, 'longitude': 24.1627545}, 'temperature_1': -20}
# {'barometric_pressure_0': 230, 'digital_out_4': 6, 'gps_2': {'altitude': 10642, 'latitude': 53.791128, 'longitude': 24.313485}, 'temperature_1': -8}
# {'barometric_pressure_0': 220, 'digital_out_4': 5, 'gps_2': {'altitude': 10660, 'latitude': 53.791128, 'longitude': 24.3200385}, 'temperature_1': -11}
# {'barometric_pressure_0': 210, 'digital_out_4': 9, 'gps_2': {'altitude': 10668, 'latitude': 53.843556, 'longitude': 24.5690715}, 'temperature_1': -7}
# {'barometric_pressure_0': 210, 'digital_out_4': 9, 'gps_2': {'altitude': 10668, 'latitude': 53.843556, 'longitude': 24.5690715}, 'temperature_1': -7}
# {'barometric_pressure_0': 130, 'digital_out_4': 12, 'gps_2': {'altitude': 10669, 'latitude': 53.856663, 'longitude': 24.6477135}, 'temperature_1': -11}
# {'barometric_pressure_0': 130, 'digital_out_4': 12, 'gps_2': {'altitude': 10669, 'latitude': 53.856663, 'longitude': 24.6477135}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10680, 'latitude': 53.8632165, 'longitude': 24.6608205}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10680, 'latitude': 53.8632165, 'longitude': 24.6608205}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 18, 'gps_2': {'altitude': 10673, 'latitude': 53.8894305, 'longitude': 24.798444}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 18, 'gps_2': {'altitude': 10673, 'latitude': 53.8894305, 'longitude': 24.798444}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10691, 'latitude': 53.9025375, 'longitude': 24.863979}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10691, 'latitude': 53.9025375, 'longitude': 24.863979}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10689, 'latitude': 53.9025375, 'longitude': 24.877086}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10689, 'latitude': 53.9025375, 'longitude': 24.877086}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10674, 'latitude': 53.9287515, 'longitude': 25.0016025}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10674, 'latitude': 53.9287515, 'longitude': 25.0016025}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10672, 'latitude': 53.9680725, 'longitude': 25.217868}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10672, 'latitude': 53.9680725, 'longitude': 25.217868}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10655, 'latitude': 53.9942865, 'longitude': 25.348938}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10655, 'latitude': 53.9942865, 'longitude': 25.348938}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10675, 'latitude': 54.0073935, 'longitude': 25.414473}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10675, 'latitude': 54.0073935, 'longitude': 25.414473}, 'temperature_1': -12}
# {'barometric_pressure_0': 120, 'digital_out_4': 7, 'gps_2': {'altitude': 10674, 'latitude': 54.0073935, 'longitude': 25.42758}, 'temperature_1': -13}
# {'barometric_pressure_0': 120, 'digital_out_4': 7, 'gps_2': {'altitude': 10674, 'latitude': 54.0073935, 'longitude': 25.42758}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10675, 'latitude': 54.0073935, 'longitude': 25.440687}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10675, 'latitude': 54.0073935, 'longitude': 25.440687}, 'temperature_1': -12}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10677, 'latitude': 54.013947, 'longitude': 25.453794}, 'temperature_1': -14}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10677, 'latitude': 54.013947, 'longitude': 25.453794}, 'temperature_1': -14}
# {'barometric_pressure_0': 220, 'digital_out_4': 6, 'gps_2': {'altitude': 10674, 'latitude': 54.0205005, 'longitude': 25.493115}, 'temperature_1': -11}
# {'barometric_pressure_0': 220, 'digital_out_4': 6, 'gps_2': {'altitude': 10674, 'latitude': 54.0205005, 'longitude': 25.493115}, 'temperature_1': -11}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10685, 'latitude': 54.0336075, 'longitude': 25.5914175}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10679, 'latitude': 54.040161, 'longitude': 25.6045245}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10679, 'latitude': 54.040161, 'longitude': 25.6045245}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10675, 'latitude': 54.040161, 'longitude': 25.6176315}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10675, 'latitude': 54.040161, 'longitude': 25.6176315}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10689, 'latitude': 54.0729285, 'longitude': 25.8273435}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 5, 'gps_2': {'altitude': 10689, 'latitude': 54.0729285, 'longitude': 25.8273435}, 'temperature_1': -12}
# {'barometric_pressure_0': 130, 'digital_out_4': 10, 'gps_2': {'altitude': 10668, 'latitude': 54.145017, 'longitude': 26.240214}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10656, 'latitude': 54.1515705, 'longitude': 26.305749}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10656, 'latitude': 54.1515705, 'longitude': 26.305749}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 12, 'gps_2': {'altitude': 10660, 'latitude': 54.1777845, 'longitude': 26.436819}, 'temperature_1': -12}
# {'barometric_pressure_0': 130, 'digital_out_4': 11, 'gps_2': {'altitude': 10660, 'latitude': 54.197445, 'longitude': 26.5744425}, 'temperature_1': -17}
# {'barometric_pressure_0': 130, 'digital_out_4': 11, 'gps_2': {'altitude': 10660, 'latitude': 54.197445, 'longitude': 26.5744425}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10644, 'latitude': 54.223659, 'longitude': 26.73828}, 'temperature_1': -13}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10646, 'latitude': 54.223659, 'longitude': 26.751387}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10646, 'latitude': 54.223659, 'longitude': 26.751387}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10651, 'latitude': 54.2302125, 'longitude': 26.764494}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10651, 'latitude': 54.2302125, 'longitude': 26.764494}, 'temperature_1': -12}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10651, 'latitude': 54.2564265, 'longitude': 26.908671}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10646, 'latitude': 54.2564265, 'longitude': 26.921778}, 'temperature_1': -19}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10646, 'latitude': 54.2564265, 'longitude': 26.921778}, 'temperature_1': -19}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10640, 'latitude': 54.2564265, 'longitude': 26.934885}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10640, 'latitude': 54.2564265, 'longitude': 26.934885}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10640, 'latitude': 54.276087, 'longitude': 27.026634}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10640, 'latitude': 54.276087, 'longitude': 27.026634}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10642, 'latitude': 54.276087, 'longitude': 27.039741}, 'temperature_1': -14}
# {'barometric_pressure_0': 190, 'digital_out_4': 10, 'gps_2': {'altitude': 10644, 'latitude': 54.2826405, 'longitude': 27.052848}, 'temperature_1': -14}
# {'barometric_pressure_0': 190, 'digital_out_4': 10, 'gps_2': {'altitude': 10644, 'latitude': 54.2826405, 'longitude': 27.052848}, 'temperature_1': -14}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10639, 'latitude': 54.302301, 'longitude': 27.170811}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10639, 'latitude': 54.302301, 'longitude': 27.170811}, 'temperature_1': -16}
# {'barometric_pressure_0': 170, 'digital_out_4': 10, 'gps_2': {'altitude': 10635, 'latitude': 54.3088545, 'longitude': 27.183918}, 'temperature_1': -14}
# {'barometric_pressure_0': 140, 'digital_out_4': 10, 'gps_2': {'altitude': 10640, 'latitude': 54.3088545, 'longitude': 27.197025}, 'temperature_1': -15}
# {'barometric_pressure_0': 140, 'digital_out_4': 10, 'gps_2': {'altitude': 10640, 'latitude': 54.3088545, 'longitude': 27.197025}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10640, 'latitude': 54.3088545, 'longitude': 27.2166855}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10640, 'latitude': 54.3088545, 'longitude': 27.2166855}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10650, 'latitude': 54.3219615, 'longitude': 27.26256}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10650, 'latitude': 54.3219615, 'longitude': 27.26256}, 'temperature_1': -17}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10641, 'latitude': 54.3481755, 'longitude': 27.4263975}, 'temperature_1': -20}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10641, 'latitude': 54.3481755, 'longitude': 27.4263975}, 'temperature_1': -20}
# {'barometric_pressure_0': 190, 'digital_out_4': 9, 'gps_2': {'altitude': 10637, 'latitude': 54.3481755, 'longitude': 27.4395045}, 'temperature_1': -18}
# {'barometric_pressure_0': 190, 'digital_out_4': 9, 'gps_2': {'altitude': 10637, 'latitude': 54.3481755, 'longitude': 27.4395045}, 'temperature_1': -18}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10632, 'latitude': 54.3481755, 'longitude': 27.4526115}, 'temperature_1': -17}
# {'barometric_pressure_0': 140, 'digital_out_4': 9, 'gps_2': {'altitude': 10632, 'latitude': 54.3481755, 'longitude': 27.4526115}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10636, 'latitude': 54.354729, 'longitude': 27.472272}, 'temperature_1': -15}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10636, 'latitude': 54.354729, 'longitude': 27.472272}, 'temperature_1': -15}
# {'barometric_pressure_0': 150, 'digital_out_4': 10, 'gps_2': {'altitude': 10631, 'latitude': 54.3612825, 'longitude': 27.537807}, 'temperature_1': -18}
# {'barometric_pressure_0': 150, 'digital_out_4': 10, 'gps_2': {'altitude': 10631, 'latitude': 54.3612825, 'longitude': 27.537807}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10631, 'latitude': 54.367836, 'longitude': 27.550914}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 10, 'gps_2': {'altitude': 10631, 'latitude': 54.367836, 'longitude': 27.550914}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10642, 'latitude': 54.3743895, 'longitude': 27.6230025}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 7, 'gps_2': {'altitude': 10642, 'latitude': 54.3743895, 'longitude': 27.6230025}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10631, 'latitude': 54.380943, 'longitude': 27.6623235}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 9, 'gps_2': {'altitude': 10631, 'latitude': 54.380943, 'longitude': 27.6623235}, 'temperature_1': -17}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10638, 'latitude': 54.39405, 'longitude': 27.7278585}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10638, 'latitude': 54.39405, 'longitude': 27.7278585}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10570, 'latitude': 54.4268175, 'longitude': 27.983445}, 'temperature_1': -14}
# {'barometric_pressure_0': 150, 'digital_out_4': 12, 'gps_2': {'altitude': 10575, 'latitude': 54.446478, 'longitude': 28.0948545}, 'temperature_1': -16}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10581, 'latitude': 54.446478, 'longitude': 28.114515}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10581, 'latitude': 54.446478, 'longitude': 28.114515}, 'temperature_1': -18}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10627, 'latitude': 54.4661385, 'longitude': 28.2390315}, 'temperature_1': -23}
# {'barometric_pressure_0': 230, 'digital_out_4': 11, 'gps_2': {'altitude': 10627, 'latitude': 54.4661385, 'longitude': 28.2390315}, 'temperature_1': -23}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10602, 'latitude': 54.485799, 'longitude': 28.376655}, 'temperature_1': -20}
# {'barometric_pressure_0': 230, 'digital_out_4': 8, 'gps_2': {'altitude': 10602, 'latitude': 54.485799, 'longitude': 28.376655}, 'temperature_1': -20}

# %%
icspace23_list
# Out:
# [{'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 0,
#   'counter': 42,
#   'payload_raw': None,
#   'metadata': {'time': '2020-12-17T12:20:54.495671829Z',
#    'frequency': 868.3,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 82432000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'eui-00800000a0004f45',
#      'timestamp': 1144040524,
#      'time': '2020-12-17T12:20:54.478213Z',
#      'channel': 1,
#      'rssi': -109,
#      'snr': -3.2,
#      'rf_chain': 0,
#      'latitude': 52.25174,
#      'longitude': 0.69729,
#      'altitude': 70},
#     {'gtw_id': 'eui-00800000a0004ead',
#      'timestamp': 1675130220,
#      'time': '',
#      'channel': 4,
#      'rssi': -116,
#      'snr': -8.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004efe',
#      'timestamp': 1053695460,
#      'time': '',
#      'channel': 4,
#      'rssi': -88,
#      'snr': -7,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03045e',
#      'timestamp': 2832480556,
#      'time': '2020-12-17T12:20:54.478055Z',
#      'channel': 1,
#      'rssi': -97,
#      'snr': 6.8,
#      'rf_chain': 0,
#      'latitude': 51.95255,
#      'longitude': 1.33882,
#      'altitude': 8},
#     {'gtw_id': 'eui-00800000a0004f43',
#      'timestamp': 2253417580,
#      'time': '2020-12-17T12:20:54.47807Z',
#      'channel': 1,
#      'rssi': -92,
#      'snr': 10,
#      'rf_chain': 0,
#      'latitude': 52.0943,
#      'longitude': 1.31133,
#      'altitude': 53},
#     {'gtw_id': 'eui-c0ee40ffff29474f',
#      'timestamp': 1178501068,
#      'time': '',
#      'channel': 1,
#      'rssi': -107,
#      'snr': -6.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0001f80',
#      'timestamp': 1685976108,
#      'time': '',
#      'channel': 4,
#      'rssi': -108,
#      'snr': -4.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004efb',
#      'timestamp': 1050504044,
#      'time': '',
#      'channel': 4,
#      'rssi': -116,
#      'snr': -4.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004db3',
#      'timestamp': 1069411156,
#      'time': '',
#      'channel': 4,
#      'rssi': -116,
#      'snr': -2.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03046b',
#      'timestamp': 2833868460,
#      'time': '2020-12-17T12:20:54.478044Z',
#      'channel': 1,
#      'rssi': -112,
#      'snr': -0.5,
#      'rf_chain': 0,
#      'latitude': 51.96733,
#      'longitude': 1.35363,
#      'altitude': 34},
#     {'gtw_id': 'eui-00800000a0004fef',
#      'timestamp': 208094636,
#      'time': '2020-12-17T12:20:54.478173Z',
#      'channel': 1,
#      'rssi': -116,
#      'snr': -4.5,
#      'rf_chain': 0,
#      'latitude': 52.2377,
#      'longitude': 0.90943,
#      'altitude': 89},
#     {'gtw_id': 'eui-00800000a0004dad',
#      'timestamp': 3361760748,
#      'time': '',
#      'channel': 4,
#      'rssi': -109,
#      'snr': 0.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ff0',
#      'timestamp': 3470667132,
#      'time': '',
#      'channel': 1,
#      'rssi': -107,
#      'snr': 6,
#      'rf_chain': 0,
#      'latitude': 52.22172,
#      'longitude': 1.34947,
#      'altitude': 47},
#     {'gtw_id': 'eui-00800000a0004da0',
#      'timestamp': 3337192964,
#      'time': '',
#      'channel': 4,
#      'rssi': -114,
#      'snr': -7.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ef4',
#      'timestamp': 1066995300,
#      'time': '',
#      'channel': 4,
#      'rssi': -116,
#      'snr': -9,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004b0c',
#      'timestamp': 1070325580,
#      'time': '',
#      'channel': 4,
#      'rssi': -116,
#      'snr': -8.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0006cdd',
#      'timestamp': 2668760540,
#      'time': '',
#      'channel': 4,
#      'rssi': -113,
#      'snr': -4,
#      'rf_chain': 0},
#     {'gtw_id': 'ipswichmakerspace-01',
#      'timestamp': 3438676348,
#      'time': '2020-12-17T12:20:54Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -4.25,
#      'rf_chain': 0},
#     {'gtw_id': 'nullmedia-03',
#      'timestamp': 1343300964,
#      'time': '2020-12-17T12:20:55Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -11,
#      'rf_chain': 0}]}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 0,
#   'counter': 42,
#   'is_retry': True,
#   'payload_raw': None,
#   'metadata': {'time': '2020-12-17T12:20:54.989168228Z',
#    'frequency': 868.3,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 82432000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'nullmedia-hq',
#      'timestamp': 1531220156,
#      'time': '2020-12-17T12:20:54Z',
#      'channel': 0,
#      'rssi': -112,
#      'snr': 5.5,
#      'rf_chain': 0}]}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 99,
#   'counter': 43,
#   'payload_raw': 'lMOwAw0AAAAAAAD6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQc=',
#   'metadata': {'time': '2020-12-17T12:24:33.231447608Z',
#    'frequency': 868.5,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 389632000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'eui-00800000a0004f43',
#      'timestamp': 2472153780,
#      'time': '2020-12-17T12:24:33.214404Z',
#      'channel': 2,
#      'rssi': -91,
#      'snr': 8.8,
#      'rf_chain': 0,
#      'latitude': 52.09423,
#      'longitude': 1.31126,
#      'altitude': 37},
#     {'gtw_id': 'eui-00800000a0001f80',
#      'timestamp': 1904712220,
#      'time': '',
#      'channel': 5,
#      'rssi': -110,
#      'snr': -3.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ef4',
#      'timestamp': 1285731428,
#      'time': '',
#      'channel': 5,
#      'rssi': -113,
#      'snr': -9.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004f44',
#      'timestamp': 202548404,
#      'time': '2020-12-17T12:24:33.214465Z',
#      'channel': 2,
#      'rssi': -104,
#      'snr': 4.5,
#      'rf_chain': 0,
#      'latitude': 52.14898,
#      'longitude': 1.05333,
#      'altitude': 35},
#     {'gtw_id': 'eui-00800000a0004b0c',
#      'timestamp': 1289061652,
#      'time': '',
#      'channel': 5,
#      'rssi': -116,
#      'snr': -4.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03045e',
#      'timestamp': 3051216628,
#      'time': '2020-12-17T12:24:33.214393Z',
#      'channel': 2,
#      'rssi': -99,
#      'snr': 9,
#      'rf_chain': 0,
#      'latitude': 51.95255,
#      'longitude': 1.33883,
#      'altitude': 9},
#     {'gtw_id': 'eui-00800000a0004f16',
#      'timestamp': 1259262556,
#      'time': '2020-12-17T12:24:33.214516Z',
#      'channel': 2,
#      'rssi': -113,
#      'snr': 0.8,
#      'rf_chain': 0,
#      'latitude': 52.4601,
#      'longitude': 1.56468,
#      'altitude': 14},
#     {'gtw_id': 'eui-00800000a0004da0',
#      'timestamp': 3555929092,
#      'time': '',
#      'channel': 5,
#      'rssi': -110,
#      'snr': 2.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004da3',
#      'timestamp': 1288669140,
#      'time': '',
#      'channel': 5,
#      'rssi': -110,
#      'snr': 2.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03046b',
#      'timestamp': 3052604740,
#      'time': '2020-12-17T12:24:33.214383Z',
#      'channel': 2,
#      'rssi': -106,
#      'snr': 7,
#      'rf_chain': 0,
#      'latitude': 51.96732,
#      'longitude': 1.35361,
#      'altitude': 30},
#     {'gtw_id': 'eui-00800000a0004efe',
#      'timestamp': 1272431652,
#      'time': '',
#      'channel': 5,
#      'rssi': -99,
#      'snr': 6.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ead',
#      'timestamp': 1893866308,
#      'time': '',
#      'channel': 5,
#      'rssi': -116,
#      'snr': -2.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004dad',
#      'timestamp': 3580496884,
#      'time': '',
#      'channel': 5,
#      'rssi': -106,
#      'snr': 5.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004f45',
#      'timestamp': 1362776708,
#      'time': '2020-12-17T12:24:33.214553Z',
#      'channel': 2,
#      'rssi': -110,
#      'snr': 2.8,
#      'rf_chain': 0,
#      'latitude': 52.2517,
#      'longitude': 0.69736,
#      'altitude': 60},
#     {'gtw_id': 'eui-00800000a0004f00',
#      'timestamp': 1354629988,
#      'time': '2020-12-17T12:24:33.214434Z',
#      'channel': 2,
#      'rssi': -114,
#      'snr': -7,
#      'rf_chain': 0,
#      'latitude': 52.05449,
#      'longitude': 1.14311,
#      'altitude': 26},
#     {'gtw_id': 'eui-00800000a0004ff0',
#      'timestamp': 3689403324,
#      'time': '',
#      'channel': 2,
#      'rssi': -108,
#      'snr': 5,
#      'rf_chain': 0,
#      'latitude': 52.22172,
#      'longitude': 1.34947,
#      'altitude': 47},
#     {'gtw_id': 'eui-00800000a0004efb',
#      'timestamp': 1269240156,
#      'time': '',
#      'channel': 5,
#      'rssi': -115,
#      'snr': -2.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004db3',
#      'timestamp': 1288147340,
#      'time': '',
#      'channel': 5,
#      'rssi': -113,
#      'snr': 0.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004dac',
#      'timestamp': 1296186012,
#      'time': '',
#      'channel': 5,
#      'rssi': -117,
#      'snr': -11.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004fef',
#      'timestamp': 426830780,
#      'time': '2020-12-17T12:24:33.214509Z',
#      'channel': 2,
#      'rssi': -114,
#      'snr': -2.2,
#      'rf_chain': 0,
#      'latitude': 52.23766,
#      'longitude': 0.90941,
#      'altitude': 82},
#     {'gtw_id': 'eui-c0ee40ffff29474f',
#      'timestamp': 1397237092,
#      'time': '',
#      'channel': 2,
#      'rssi': -105,
#      'snr': -4.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0006cdd',
#      'timestamp': 2887496748,
#      'time': '',
#      'channel': 5,
#      'rssi': -115,
#      'snr': -1.8,
#      'rf_chain': 0},
#     {'gtw_id': 'nullmedia-03',
#      'timestamp': 1562037476,
#      'time': '2020-12-17T12:24:33Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -1.5,
#      'rf_chain': 0},
#     {'gtw_id': 'ipswichmakerspace-01',
#      'timestamp': 3657412188,
#      'time': '2020-12-17T12:24:33Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -0.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a00033d9',
#      'timestamp': 1242504444,
#      'time': '2020-12-17T12:24:33.214591Z',
#      'channel': 2,
#      'rssi': -117,
#      'snr': -11.2,
#      'rf_chain': 0,
#      'latitude': 52.62399,
#      'longitude': 1.10537,
#      'altitude': 49}]},
#   'payload_fields': {'barometric_pressure_0': 880,
#    'digital_out_4': 0,
#    'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0},
#    'temperature_1': 13}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 99,
#   'counter': 43,
#   'is_retry': True,
#   'payload_raw': 'lMOwAw0AAAAAAAD6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQc=',
#   'metadata': {'time': '2020-12-17T12:24:33.8397392Z',
#    'frequency': 868.5,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 389632000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'nullmedia-hq',
#      'timestamp': 1749956236,
#      'time': '2020-12-17T12:24:33Z',
#      'channel': 0,
#      'rssi': -111,
#      'snr': 6.5,
#      'rf_chain': 0}]},
#   'payload_fields': {'barometric_pressure_0': 880,
#    'digital_out_4': 0,
#    'gps_2': {'altitude': 0, 'latitude': 0.0, 'longitude': 0.0},
#    'temperature_1': 13}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 99,
#   'counter': 44,
#   'payload_raw': 'jE+4Iw0AH+sAaQ36HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQf6HtEACQFmYQf6HtEAhgIRfQf6HtEA6QAErgf6HtEA4wBCYQc=',
#   'metadata': {'time': '2020-12-17T12:27:13.560152783Z',
#    'frequency': 868.1,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 389632000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'eui-00800000a0004f43',
#      'timestamp': 2632486980,
#      'time': '2020-12-17T12:27:13.547704Z',
#      'channel': 0,
#      'rssi': -95,
#      'snr': 11.2,
#      'rf_chain': 0,
#      'latitude': 52.09426,
#      'longitude': 1.31127,
#      'altitude': 47},
#     {'gtw_id': 'eui-00800000a0001f80',
#      'timestamp': 2065045356,
#      'time': '',
#      'channel': 3,
#      'rssi': -111,
#      'snr': 2.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03045e',
#      'timestamp': 3211549732,
#      'time': '2020-12-17T12:27:13.547692Z',
#      'channel': 0,
#      'rssi': -98,
#      'snr': -5,
#      'rf_chain': 0,
#      'latitude': 51.95255,
#      'longitude': 1.33882,
#      'altitude': 6},
#     {'gtw_id': 'eui-00800000a0004db1',
#      'timestamp': 3804060436,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -6.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ead',
#      'timestamp': 2054199428,
#      'time': '',
#      'channel': 3,
#      'rssi': -113,
#      'snr': 3,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ea8',
#      'timestamp': 1558922732,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -5.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004db3',
#      'timestamp': 1448480524,
#      'time': '',
#      'channel': 3,
#      'rssi': -113,
#      'snr': 4,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004db7',
#      'timestamp': 3647665524,
#      'time': '',
#      'channel': 3,
#      'rssi': -114,
#      'snr': -1.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004dab',
#      'timestamp': 1470485956,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -6.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004efb',
#      'timestamp': 1429573292,
#      'time': '',
#      'channel': 3,
#      'rssi': -115,
#      'snr': 0.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004c41',
#      'timestamp': 2181258620,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -7,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004f44',
#      'timestamp': 362881660,
#      'time': '2020-12-17T12:27:13.547765Z',
#      'channel': 0,
#      'rssi': -104,
#      'snr': 1.2,
#      'rf_chain': 0,
#      'latitude': 52.14897,
#      'longitude': 1.05338,
#      'altitude': 31},
#     {'gtw_id': 'eui-00800000a0004b0c',
#      'timestamp': 1449394756,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -6.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004dae',
#      'timestamp': 1287377796,
#      'time': '',
#      'channel': 3,
#      'rssi': -116,
#      'snr': -7.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004fef',
#      'timestamp': 587163940,
#      'time': '2020-12-17T12:27:13.54781Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -4,
#      'rf_chain': 0,
#      'latitude': 52.23762,
#      'longitude': 0.90937,
#      'altitude': 72},
#     {'gtw_id': 'eui-00800000a0004dad',
#      'timestamp': 3740830036,
#      'time': '',
#      'channel': 3,
#      'rssi': -107,
#      'snr': 6.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ef2',
#      'timestamp': 3849802276,
#      'time': '',
#      'channel': 3,
#      'rssi': -111,
#      'snr': -9,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ff0',
#      'timestamp': 3849736524,
#      'time': '',
#      'channel': 0,
#      'rssi': -107,
#      'snr': 5.5,
#      'rf_chain': 0,
#      'latitude': 52.22172,
#      'longitude': 1.34947,
#      'altitude': 47},
#     {'gtw_id': 'eui-00800000a0006cdd',
#      'timestamp': 3047829948,
#      'time': '',
#      'channel': 3,
#      'rssi': -113,
#      'snr': -1,
#      'rf_chain': 0},
#     {'gtw_id': 'nullmedia-03',
#      'timestamp': 1722370908,
#      'time': '2020-12-17T12:27:14Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': 0.5,
#      'rf_chain': 0}]},
#   'payload_fields': {'barometric_pressure_0': 920,
#    'digital_out_4': 4,
#    'gps_2': {'altitude': 875, 'latitude': 52.008576, 'longitude': 1.5400725},
#    'temperature_1': 13}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'hardware_serial': '0093BECA9134091B',
#   'port': 0,
#   'counter': 45,
#   'payload_raw': None,
#   'metadata': {'time': '2020-12-17T14:51:31.414388821Z',
#    'frequency': 868.1,
#    'modulation': 'LORA',
#    'data_rate': 'SF8BW125',
#    'airtime': 82432000,
#    'coding_rate': '4/5',
#    'gateways': [{'gtw_id': 'eui-0000024b080e0bf0',
#      'timestamp': 1454575740,
#      'time': '2020-12-17T14:51:31.401902Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -2.5,
#      'rf_chain': 0,
#      'latitude': 52.23531,
#      'longitude': 5.17222,
#      'altitude': 16},
#     {'gtw_id': 'eui-0000024b0803009a',
#      'timestamp': 2815103820,
#      'time': '2020-12-17T14:51:31.402013Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -5.5,
#      'rf_chain': 0,
#      'latitude': 52.35873,
#      'longitude': 5.61535,
#      'altitude': 22},
#     {'gtw_id': 'eui-7276ff00390301f2',
#      'timestamp': 2548615140,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 5,
#      'rssi': -115,
#      'snr': 4.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe2055d4',
#      'timestamp': 161083764,
#      'time': '2020-12-17T14:51:31.404187Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -6.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b0b03045e',
#      'timestamp': 3279459180,
#      'time': '2020-12-17T14:51:31.402249Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': 0.8,
#      'rf_chain': 0,
#      'latitude': 51.95258,
#      'longitude': 1.33885,
#      'altitude': 11},
#     {'gtw_id': 'mjs-gateway-3',
#      'timestamp': 208892572,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -8.25,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-1dee1f5bc563aa18',
#      'timestamp': 3998557876,
#      'time': '',
#      'channel': 0,
#      'rssi': -111,
#      'snr': -7.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffefb73a2',
#      'timestamp': 2065262365,
#      'time': '2020-12-17T14:51:30.401924Z',
#      'channel': 0,
#      'rssi': -116,
#      'snr': -4.8,
#      'rf_chain': 0,
#      'latitude': 52.01459,
#      'longitude': 5.33305,
#      'altitude': 4},
#     {'gtw_id': 'ttne-fffeb827ebea907e',
#      'timestamp': 1241781700,
#      'time': '2020-12-17T14:51:31.402027Z',
#      'channel': 0,
#      'rssi': -112,
#      'snr': -8.75,
#      'rf_chain': 0,
#      'latitude': 51.912376,
#      'longitude': 5.8274345,
#      'altitude': 8},
#     {'gtw_id': 'eui-0000024b0806028a',
#      'timestamp': 2150416572,
#      'time': '2020-12-17T14:51:31.401706Z',
#      'channel': 0,
#      'rssi': -108,
#      'snr': 4.8,
#      'rf_chain': 0,
#      'latitude': 51.92369,
#      'longitude': 4.43269,
#      'altitude': 28},
#     {'gtw_id': 'gateway_sint_anthonis_005',
#      'timestamp': 2140698116,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -5.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe0aa244',
#      'timestamp': 1233386916,
#      'time': '2020-12-17T14:51:31.405271Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -2,
#      'rf_chain': 0,
#      'latitude': 51.9845,
#      'longitude': 7.637,
#      'altitude': -1},
#     {'gtw_id': 'eui-b827ebfffefc1bae',
#      'timestamp': 3586338980,
#      'time': '2020-12-17T14:51:31.404626Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -1,
#      'rf_chain': 0,
#      'latitude': 52.17271,
#      'longitude': 4.99913,
#      'altitude': 2},
#     {'gtw_id': 'ttn_apeldoorn_stadhuis',
#      'timestamp': 1385764372,
#      'time': '2020-12-17T14:51:31.402072Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': 0.5,
#      'rf_chain': 0,
#      'latitude': 52.215847,
#      'longitude': 5.9637504,
#      'altitude': 37},
#     {'gtw_id': 'eui-fcc23dfffe20c383',
#      'timestamp': 1595653756,
#      'time': '2020-12-17T14:51:31.406278Z',
#      'channel': 0,
#      'rssi': -112,
#      'snr': -5.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffe34bb20',
#      'timestamp': 938153708,
#      'time': '2020-12-17T14:51:31.404784Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -9.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-ac1f09fffe0147ba',
#      'timestamp': 318762132,
#      'time': '',
#      'channel': 0,
#      'rssi': -128,
#      'snr': -10.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-474bfcc23dfffe0f',
#      'timestamp': 3439644060,
#      'time': '2020-12-17T14:51:31.405555Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -0.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-ac1f09fffe014240',
#      'timestamp': 3769982324,
#      'time': '',
#      'channel': 0,
#      'rssi': -123,
#      'snr': -6.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-323531323f007100',
#      'timestamp': 1875830384,
#      'time': '',
#      'channel': 0,
#      'rssi': -115,
#      'snr': 1.25,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b08031d4f',
#      'timestamp': 366176212,
#      'time': '2020-12-17T14:51:31.402008Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -8,
#      'rf_chain': 0,
#      'latitude': 52.33554,
#      'longitude': 5.60645,
#      'altitude': 5},
#     {'gtw_id': 'eui-b827ebfffe456a88',
#      'timestamp': 3993638460,
#      'time': '2020-12-17T14:51:31.404121Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -3,
#      'rf_chain': 0,
#      'latitude': 51.35892,
#      'longitude': 5.46301},
#     {'gtw_id': 'eui-00800000a00037a1',
#      'timestamp': 1505549724,
#      'time': '',
#      'channel': 3,
#      'rssi': -119,
#      'snr': -7.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-7276ff000b032593',
#      'timestamp': 1287538460,
#      'time': '2020-12-17T14:51:31.402085Z',
#      'channel': 5,
#      'rssi': -117,
#      'snr': -6.5,
#      'rf_chain': 0,
#      'latitude': 50.66962,
#      'longitude': 4.61934,
#      'altitude': 144},
#     {'gtw_id': 'eui-a840411bcd244150',
#      'timestamp': 1541800140,
#      'time': '',
#      'channel': 0,
#      'rssi': -116,
#      'snr': -1.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0001f80',
#      'timestamp': 2132956796,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -7,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-7276ff000805024f',
#      'timestamp': 917254828,
#      'time': '2020-12-17T14:51:31.401773Z',
#      'channel': 5,
#      'rssi': -122,
#      'snr': -5.5,
#      'rf_chain': 0,
#      'latitude': 52.02139,
#      'longitude': 4.71005,
#      'altitude': -2},
#     {'gtw_id': 'eui-fcc23dfffe0a7e59',
#      'timestamp': 648394548,
#      'time': '2020-12-17T14:51:31.435251Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': 0.5,
#      'rf_chain': 0},
#     {'gtw_id': 'ttn-gent-1',
#      'timestamp': 956919188,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -111,
#      'snr': 4.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-1dee03451ab7b257',
#      'timestamp': 2844099108,
#      'time': '',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -5.8,
#      'rf_chain': 0,
#      'latitude': 52.77814,
#      'longitude': 6.91334,
#      'altitude': 50},
#     {'gtw_id': 'ttn_apeldoorn_hoenderloo',
#      'timestamp': 3991337884,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -0.5,
#      'rf_chain': 0,
#      'latitude': 52.117012,
#      'longitude': 5.873205,
#      'altitude': 14},
#     {'gtw_id': 'eui-0000024b080606d8',
#      'timestamp': 3962794084,
#      'time': '2020-12-17T14:51:31.401848Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': 3.2,
#      'rf_chain': 0,
#      'latitude': 52.38173,
#      'longitude': 4.62981,
#      'altitude': 22},
#     {'gtw_id': 'eui-0000024b08030919',
#      'timestamp': 1056331916,
#      'time': '2020-12-17T14:51:31.401851Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -8,
#      'rf_chain': 0,
#      'latitude': 52.01005,
#      'longitude': 5.05345,
#      'altitude': 69},
#     {'gtw_id': 'eui-1dee156c4ac7ef65',
#      'timestamp': 1902416012,
#      'time': '',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -3,
#      'rf_chain': 0,
#      'latitude': 52.22987,
#      'longitude': 5.1792,
#      'altitude': 20},
#     {'gtw_id': 'eui-60c5a8fffe766473',
#      'timestamp': 1615136527,
#      'time': '2020-12-17T14:51:31.400249Z',
#      'channel': 5,
#      'rssi': -114,
#      'snr': -1,
#      'rf_chain': 0,
#      'latitude': 52.40803,
#      'longitude': 4.82156,
#      'altitude': 7},
#     {'gtw_id': 'kelaquanl19',
#      'gtw_trusted': True,
#      'timestamp': 3329589140,
#      'time': '',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -4.5,
#      'rf_chain': 1},
#     {'gtw_id': 'eui-3436323821002c00',
#      'timestamp': 177843357,
#      'time': '2020-12-17T14:50:25.750884Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -6.25,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b080e02cf',
#      'timestamp': 627265124,
#      'time': '2020-12-17T14:51:31.409337Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -0.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b08031193',
#      'timestamp': 4111534868,
#      'time': '2020-12-17T14:51:31.402009Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -3.2,
#      'rf_chain': 0,
#      'latitude': 52.32587,
#      'longitude': 5.59078,
#      'altitude': 13},
#     {'gtw_id': 'eui-1dee9ef5cafa861f',
#      'timestamp': 1537041836,
#      'time': '',
#      'channel': 0,
#      'rssi': -113,
#      'snr': 1.5,
#      'rf_chain': 0,
#      'latitude': 52.29013,
#      'longitude': 4.58043,
#      'altitude': 7},
#     {'gtw_id': 'eui-7276ff000b0322e1',
#      'timestamp': 1074402908,
#      'time': '2020-12-17T14:51:31.402081Z',
#      'channel': 5,
#      'rssi': -120,
#      'snr': -1,
#      'rf_chain': 0,
#      'latitude': 50.66994,
#      'longitude': 4.61142,
#      'altitude': 131},
#     {'gtw_id': 'eui-b827eba64bf5ffff',
#      'timestamp': 3642781924,
#      'time': '2020-12-17T14:51:31.403679Z',
#      'channel': 0,
#      'rssi': -130,
#      'snr': -10,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe0f0bc2',
#      'timestamp': 1237422820,
#      'time': '2020-12-16T18:15:37.641408Z',
#      'channel': 0,
#      'rssi': -110,
#      'snr': -1.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffefe7366',
#      'timestamp': 3808704788,
#      'time': '2020-12-17T14:51:31.397214Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -8,
#      'rf_chain': 0,
#      'latitude': 51.50188,
#      'longitude': 5.77906},
#     {'gtw_id': 'eui-00800000a0004b0c',
#      'timestamp': 1517303676,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -4.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-7276ff000b031df2',
#      'timestamp': 1080233988,
#      'time': '2020-12-17T14:51:31.401764Z',
#      'channel': 5,
#      'rssi': -116,
#      'snr': -1.5,
#      'rf_chain': 0,
#      'latitude': 51.6746,
#      'longitude': 4.60617,
#      'altitude': 19},
#     {'gtw_id': 'eui-b827ebfffef37f7f',
#      'timestamp': 2816744804,
#      'time': '',
#      'channel': 0,
#      'rssi': -119,
#      'snr': 1.2,
#      'rf_chain': 0,
#      'latitude': 52.20537,
#      'longitude': 4.85868},
#     {'gtw_id': 'eui-0000024b0803114c',
#      'timestamp': 422074756,
#      'time': '2020-12-17T14:51:31.402023Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -9.2,
#      'rf_chain': 0,
#      'latitude': 52.34704,
#      'longitude': 5.6532,
#      'altitude': 3},
#     {'gtw_id': 'eui-0000024b0806044c',
#      'timestamp': 4045923404,
#      'time': '2020-12-17T14:51:31.401721Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': 1.5,
#      'rf_chain': 0,
#      'latitude': 51.9172,
#      'longitude': 4.48387,
#      'altitude': 23},
#     {'gtw_id': 'eui-0000024b08060779',
#      'timestamp': 3844407748,
#      'time': '2020-12-17T14:51:31.401865Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -7.2,
#      'rf_chain': 0,
#      'latitude': 52.13526,
#      'longitude': 5.03357,
#      'altitude': 25},
#     {'gtw_id': 'eui-fcc23dfffe0a8929',
#      'timestamp': 3475126236,
#      'time': '2020-12-17T14:51:31.406891Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -9,
#      'rf_chain': 0,
#      'latitude': 51.9401,
#      'longitude': 7.7039,
#      'altitude': -1},
#     {'gtw_id': 'eui-00800000a0002abc',
#      'timestamp': 3174814804,
#      'time': '2020-12-17T14:51:31.401868Z',
#      'channel': 0,
#      'rssi': -109,
#      'snr': 1.8,
#      'rf_chain': 0,
#      'latitude': 51.24574,
#      'longitude': 4.35304,
#      'altitude': 38},
#     {'gtw_id': 'eui-0000024b08031dee',
#      'timestamp': 2513030212,
#      'time': '2020-12-17T14:51:31.402012Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -1.5,
#      'rf_chain': 0,
#      'latitude': 52.35029,
#      'longitude': 5.61867,
#      'altitude': 17},
#     {'gtw_id': 'gateway_proeftuin_randwijk',
#      'timestamp': 331265468,
#      'time': '2020-12-17T15:08:30Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -3.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-c0ee40ffff293912',
#      'gtw_trusted': True,
#      'timestamp': 3312591860,
#      'time': '',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -7,
#      'rf_chain': 1,
#      'latitude': 52.318493,
#      'longitude': 4.6441627,
#      'altitude': 5},
#     {'gtw_id': 'ttn-gent-2',
#      'timestamp': 887999980,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': 0,
#      'rf_chain': 0},
#     {'gtw_id': 'gateway_berrybrothers',
#      'timestamp': 2981373820,
#      'time': '2020-12-17T15:12:09Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -7.25,
#      'rf_chain': 0},
#     {'gtw_id': 'iotsteenbergen',
#      'gtw_trusted': True,
#      'timestamp': 3709750396,
#      'time': '',
#      'channel': 0,
#      'rssi': -124,
#      'snr': -10,
#      'rf_chain': 1,
#      'latitude': 51.59229,
#      'longitude': 4.3277516},
#     {'gtw_id': 'eui-b827ebfffeea3112',
#      'timestamp': 239993388,
#      'time': '2020-12-17T14:51:31.406766Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': 1.5,
#      'rf_chain': 0,
#      'latitude': 51.5345,
#      'longitude': 4.46191,
#      'altitude': 12},
#     {'gtw_id': 'eui-b827ebfffefa3bb9',
#      'timestamp': 3010334652,
#      'time': '2020-12-17T14:51:31.412613Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -8.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b080604ba',
#      'timestamp': 2397436404,
#      'time': '2020-12-17T14:51:30.713284015Z',
#      'channel': 0,
#      'rssi': -109,
#      'snr': 4.25,
#      'rf_chain': 0},
#     {'gtw_id': 'home-made-second-ic880a-rpi3',
#      'gtw_trusted': True,
#      'timestamp': 3312934020,
#      'time': '',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -3.5,
#      'rf_chain': 1,
#      'latitude': 51.954266,
#      'longitude': 5.90666,
#      'altitude': 55},
#     {'gtw_id': '0008004a242f',
#      'timestamp': 1207092324,
#      'time': '2020-12-17T15:56:20Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -8.75,
#      'rf_chain': 0},
#     {'gtw_id': 'd5e35cee4a19',
#      'timestamp': 472794740,
#      'time': '2020-12-17T15:11:03Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': 4,
#      'rf_chain': 0},
#     {'gtw_id': 'w4e-1424ar-002',
#      'timestamp': 3135799924,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -121,
#      'snr': -9,
#      'rf_chain': 0,
#      'latitude': 52.23985,
#      'longitude': 4.79,
#      'altitude': -5},
#     {'gtw_id': 'eui-ff01020304050607',
#      'timestamp': 2728212980,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -108,
#      'snr': -4.5,
#      'rf_chain': 0,
#      'latitude': 51.484234,
#      'longitude': 4.45691},
#     {'gtw_id': 'eui-b827eb9c880dffff',
#      'timestamp': 4238614308,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': 3.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fffeb827eb6ebdc4',
#      'timestamp': 3707715020,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -8,
#      'rf_chain': 0,
#      'latitude': 51.48704,
#      'longitude': 5.4823656,
#      'altitude': 11},
#     {'gtw_id': 'eui-b827ebfffe257894',
#      'timestamp': 1894034996,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -4.5,
#      'rf_chain': 0},
#     {'gtw_id': 'gerluy-vlezenbeek-01',
#      'timestamp': 136167012,
#      'time': '2020-12-17T16:18:30Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -0.5,
#      'rf_chain': 0},
#     {'gtw_id': 'berkenrijs',
#      'timestamp': 3737718580,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -3.5,
#      'rf_chain': 0,
#      'latitude': 51.374016,
#      'longitude': 4.5161533,
#      'altitude': 10},
#     {'gtw_id': 'winkelcentrum_ac',
#      'timestamp': 3058086628,
#      'time': '2020-12-17T15:08:28Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-58a0cbfffe801160',
#      'timestamp': 242198804,
#      'time': '2020-12-17T14:51:31.397448062Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -1.5,
#      'rf_chain': 0},
#     {'gtw_id': 'gateway_sint_anthonis_002',
#      'timestamp': 4262154860,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -8.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-58a0cbfffe801e39',
#      'timestamp': 206713708,
#      'time': '2020-12-17T14:51:31.474195957Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -7,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fffeb827eb75534e',
#      'timestamp': 2239026428,
#      'time': '2020-12-17T14:51:31.401961Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -8.5,
#      'rf_chain': 0,
#      'latitude': 51.45394,
#      'longitude': 5.40207,
#      'altitude': 59},
#     {'gtw_id': 'eui-0000024b0803118d',
#      'timestamp': 3590272828,
#      'time': '2020-12-17T14:51:31.402028Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -4.8,
#      'rf_chain': 0,
#      'latitude': 52.35868,
#      'longitude': 5.67842,
#      'altitude': 8},
#     {'gtw_id': 'eui-b827ebfffef42c53',
#      'timestamp': 466752444,
#      'time': '2020-12-17T14:51:31.407786Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -11.2,
#      'rf_chain': 0,
#      'latitude': 52.7516,
#      'longitude': 6.93598,
#      'altitude': -1},
#     {'gtw_id': 'eui-0000024b080e0ffd',
#      'timestamp': 4108921452,
#      'time': '2020-12-17T14:51:31.40187Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -3,
#      'rf_chain': 0,
#      'latitude': 52.08565,
#      'longitude': 5.10924,
#      'altitude': 106},
#     {'gtw_id': 'eui-fcc23dfffe10616f',
#      'timestamp': 1498761604,
#      'time': '2020-12-17T14:51:31.408297Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -5.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-000080029c09ded1',
#      'timestamp': 621917876,
#      'time': '2020-12-17T14:51:31.402273Z',
#      'channel': 5,
#      'rssi': -118,
#      'snr': -8.8,
#      'rf_chain': 0,
#      'latitude': 52.22128,
#      'longitude': 6.90715,
#      'altitude': 58},
#     {'gtw_id': 'eui-00800000a0004eac',
#      'timestamp': 1507322684,
#      'time': '',
#      'channel': 3,
#      'rssi': -119,
#      'snr': -6.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-000080029c48d3a0',
#      'timestamp': 845813964,
#      'time': '2020-12-17T14:51:31.402076Z',
#      'channel': 5,
#      'rssi': -119,
#      'snr': -3.5,
#      'rf_chain': 0,
#      'latitude': 51.51713,
#      'longitude': 5.98327,
#      'altitude': 18},
#     {'gtw_id': 'eui-1dee089cbe020e14',
#      'timestamp': 3706254532,
#      'time': '',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -10.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-a840411d1de44150',
#      'timestamp': 865071980,
#      'time': '2020-12-17T14:51:31.409268Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -1,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffe2717df',
#      'timestamp': 4054408700,
#      'time': '2020-12-17T14:51:30.402123Z',
#      'channel': 0,
#      'rssi': -123,
#      'snr': -6.2,
#      'rf_chain': 0,
#      'latitude': 52.16407,
#      'longitude': 6.23751,
#      'altitude': 8},
#     {'gtw_id': 'eui-3235313217003400',
#      'timestamp': 3355893868,
#      'time': '2020-12-17T14:51:31.398396Z',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -10.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe0aa6e3',
#      'timestamp': 164387452,
#      'time': '2020-05-19T19:36:42.788065Z',
#      'channel': 0,
#      'rssi': -106,
#      'snr': 7,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0004ead',
#      'timestamp': 2122109500,
#      'time': '',
#      'channel': 3,
#      'rssi': -117,
#      'snr': -5.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b080e020a',
#      'timestamp': 3620236684,
#      'time': '2020-12-17T14:51:31.401935Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -5.5,
#      'rf_chain': 0,
#      'latitude': 52.15438,
#      'longitude': 5.37998,
#      'altitude': 31},
#     {'gtw_id': 'eui-58a0cbfffe80204f',
#      'timestamp': 1832089964,
#      'time': '2020-12-17T14:51:31.430845022Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': 0.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-58a0cbfffe80292e',
#      'timestamp': 1526989436,
#      'time': '2020-12-17T14:51:31.478308916Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -10,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-58a0cbfffe800569',
#      'timestamp': 3667282700,
#      'time': '2020-12-17T14:51:31.479017019Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': -5.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-7066ff00ff020a85',
#      'timestamp': 3874633908,
#      'time': '',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -10.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe0f9843',
#      'timestamp': 3330059820,
#      'time': '2020-12-17T14:51:31.410846Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -5,
#      'rf_chain': 0,
#      'latitude': 51.9509,
#      'longitude': 7.6384,
#      'altitude': -1},
#     {'gtw_id': 'eui-0000024b080e0c15',
#      'timestamp': 2457589540,
#      'time': '2020-12-17T14:51:31.401936Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -1,
#      'rf_chain': 0,
#      'latitude': 52.61757,
#      'longitude': 4.76677,
#      'altitude': 19},
#     {'gtw_id': 'eui-fb10b827eba1fe6c',
#      'timestamp': 1100474532,
#      'time': '2020-12-17T14:51:31.405252Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -8.2,
#      'rf_chain': 0,
#      'latitude': 52.13283,
#      'longitude': 5.22331,
#      'altitude': 18},
#     {'gtw_id': 'eui-000080029c10db19',
#      'timestamp': 2147278876,
#      'time': '',
#      'channel': 5,
#      'rssi': -120,
#      'snr': -8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffe38a9ca',
#      'timestamp': 3504268476,
#      'time': '2020-12-17T14:51:31.409389Z',
#      'channel': 0,
#      'rssi': -111,
#      'snr': -10,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-1dee192e3d82b8e4',
#      'timestamp': 2109216932,
#      'time': '2020-12-17T14:51:31.411406Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -7.5,
#      'rf_chain': 0,
#      'latitude': 52.23985,
#      'longitude': 4.79},
#     {'gtw_id': 'eui-7276ff000b031d84',
#      'timestamp': 1044302548,
#      'time': '2020-12-17T14:51:31.401971Z',
#      'channel': 5,
#      'rssi': -123,
#      'snr': -6,
#      'rf_chain': 0,
#      'latitude': 50.93903,
#      'longitude': 4.04263,
#      'altitude': 40},
#     {'gtw_id': 'eui-b827ebbf4634ffff',
#      'timestamp': 1684473756,
#      'time': '2020-12-17T14:52:20.255502Z',
#      'channel': 0,
#      'rssi': -113,
#      'snr': 0.5,
#      'rf_chain': 0,
#      'latitude': 51.49806,
#      'longitude': 5.3922,
#      'altitude': 13},
#     {'gtw_id': 'eui-3235313219004000',
#      'timestamp': 3171507867,
#      'time': '2020-12-17T14:51:31.406187Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -3,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffe0e8065',
#      'timestamp': 339891500,
#      'time': '2020-12-17T14:51:31.410746Z',
#      'channel': 0,
#      'rssi': -108,
#      'snr': -2.8,
#      'rf_chain': 0,
#      'latitude': 52.08866,
#      'longitude': 5.22072,
#      'altitude': 7},
#     {'gtw_id': 'eui-000080029c55ef80',
#      'timestamp': 3565888004,
#      'time': '2020-12-17T14:51:31.402082Z',
#      'channel': 5,
#      'rssi': -114,
#      'snr': 0.8,
#      'rf_chain': 0,
#      'latitude': 51.54746,
#      'longitude': 5.99759,
#      'altitude': 23},
#     {'gtw_id': 'eui-0000024b08060549',
#      'timestamp': 1341957468,
#      'time': '2020-12-17T14:51:31.401743Z',
#      'channel': 0,
#      'rssi': -118,
#      'snr': -0.2,
#      'rf_chain': 0,
#      'latitude': 52.06765,
#      'longitude': 4.50311,
#      'altitude': 9},
#     {'gtw_id': 'eui-1dee05dd505b87dc',
#      'timestamp': 3298560820,
#      'time': '',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -9.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-3235313217003c00',
#      'timestamp': 2811289012,
#      'time': '2020-12-17T14:51:31.40145Z',
#      'channel': 0,
#      'rssi': -109,
#      'snr': 5.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffeaa660c',
#      'timestamp': 4162690884,
#      'time': '2020-12-17T14:51:31.407164Z',
#      'channel': 0,
#      'rssi': -122,
#      'snr': -6.2,
#      'rf_chain': 0,
#      'latitude': 52.05865,
#      'longitude': 4.23041,
#      'altitude': 30},
#     {'gtw_id': 'eui-58a0cbfffe801ab6',
#      'timestamp': 1498767980,
#      'time': '2020-12-17T14:51:31.375013113Z',
#      'channel': 0,
#      'rssi': -112,
#      'snr': 0.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0002689',
#      'timestamp': 2721069252,
#      'time': '2020-12-17T14:51:31.40185Z',
#      'channel': 0,
#      'rssi': -111,
#      'snr': 2.2,
#      'rf_chain': 0,
#      'latitude': 51.28208,
#      'longitude': 4.33942,
#      'altitude': 49},
#     {'gtw_id': 'eui-0000024b080301bf',
#      'timestamp': 933787572,
#      'time': '2020-12-17T14:51:31.40227Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -3.8,
#      'rf_chain': 0,
#      'latitude': 52.23997,
#      'longitude': 6.85015,
#      'altitude': 55},
#     {'gtw_id': 'eui-0000024b080e015b',
#      'timestamp': 118222820,
#      'time': '2020-12-17T14:51:31.402051Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -8.5,
#      'rf_chain': 0,
#      'latitude': 51.96754,
#      'longitude': 5.94103,
#      'altitude': 37},
#     {'gtw_id': 'eui-00800000a0004f44',
#      'timestamp': 430798956,
#      'time': '2020-12-17T14:51:31.402321Z',
#      'channel': 0,
#      'rssi': -116,
#      'snr': -7.2,
#      'rf_chain': 0,
#      'latitude': 52.14894,
#      'longitude': 1.05334,
#      'altitude': 41},
#     {'gtw_id': 'eui-0000024b08031cf9',
#      'timestamp': 398545532,
#      'time': '',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -7.2,
#      'rf_chain': 0,
#      'latitude': 51.94064,
#      'longitude': 4.3879,
#      'altitude': -12},
#     {'gtw_id': 'eui-b827ebfffef1dac5',
#      'timestamp': 1284496564,
#      'time': '2020-12-17T14:51:28.402102Z',
#      'channel': 5,
#      'rssi': -113,
#      'snr': -5,
#      'rf_chain': 0,
#      'latitude': 51.20525,
#      'longitude': 5.8479,
#      'altitude': 39},
#     {'gtw_id': 'eui-00800000a0004f00',
#      'timestamp': 1582874468,
#      'time': '2020-12-17T14:51:31.402292Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -11.2,
#      'rf_chain': 0,
#      'latitude': 52.05442,
#      'longitude': 1.1431,
#      'altitude': 24},
#     {'gtw_id': 'eui-aa555a00080e051e',
#      'timestamp': 2881667908,
#      'time': '2020-12-17T14:51:31.401838Z',
#      'channel': 0,
#      'rssi': -112,
#      'snr': 4.2,
#      'rf_chain': 0,
#      'latitude': 52.28014,
#      'longitude': 4.74653,
#      'altitude': 14},
#     {'gtw_id': 'eui-008000000000aa8a',
#      'timestamp': 3641232004,
#      'time': '2020-12-17T14:31:06Z',
#      'channel': 0,
#      'rssi': -120,
#      'snr': -10.25,
#      'rf_chain': 0,
#      'latitude': 52.85918,
#      'longitude': 6.309207,
#      'altitude': 6},
#     {'gtw_id': 'eui-000080029c10dc4a',
#      'timestamp': 3797628516,
#      'time': '2020-12-17T14:51:31.401785Z',
#      'channel': 5,
#      'rssi': -112,
#      'snr': 5.5,
#      'rf_chain': 0,
#      'latitude': 52.05591,
#      'longitude': 4.72705,
#      'altitude': -2},
#     {'gtw_id': 'eui-58a0cbfffe801f6c',
#      'timestamp': 438029524,
#      'time': '2020-12-17T14:51:31.44552803Z',
#      'channel': 0,
#      'rssi': -114,
#      'snr': -8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-c0ee40ffff29392e',
#      'timestamp': 3291396268,
#      'time': '',
#      'channel': 0,
#      'rssi': -128,
#      'snr': -6.5,
#      'rf_chain': 1,
#      'latitude': 51.298573,
#      'longitude': 1.0701817,
#      'altitude': 9},
#     {'gtw_id': 'eui-58a0cbfffe801a57',
#      'timestamp': 1455208764,
#      'time': '2020-12-17T14:51:31.439687013Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -3.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-00800000a0005396',
#      'timestamp': 1083680900,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -8.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-647fdafffe005931',
#      'timestamp': 241871484,
#      'time': '',
#      'channel': 55,
#      'rssi': -94,
#      'snr': -11.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0908070605040302',
#      'timestamp': 1765289628,
#      'time': '2020-12-17T14:51:49.386319Z',
#      'channel': 5,
#      'rssi': -113,
#      'snr': -5.5,
#      'rf_chain': 0,
#      'latitude': 51.18322,
#      'longitude': 7.22181,
#      'altitude': 391},
#     {'gtw_id': 'eui-fcc23dfffe0b89d4',
#      'timestamp': 3417742164,
#      'time': '',
#      'channel': 0,
#      'rssi': -111,
#      'snr': -11,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-3235313213003400',
#      'timestamp': 258448272,
#      'time': '2020-12-17T14:50:42.436266Z',
#      'channel': 0,
#      'rssi': -116,
#      'snr': -5.5,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-3133303747002a00',
#      'timestamp': 3297134878,
#      'time': '2020-12-17T14:50:48.288154Z',
#      'channel': 0,
#      'rssi': -111,
#      'snr': 0,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0001fcc23d0f3785',
#      'timestamp': 2543636580,
#      'time': '2020-12-17T14:51:31.417601Z',
#      'channel': 0,
#      'rssi': -115,
#      'snr': -6.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-0000024b08030ea5',
#      'timestamp': 202691540,
#      'time': '',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -8.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-3133303714004800',
#      'timestamp': 186409156,
#      'time': '',
#      'channel': 0,
#      'rssi': -117,
#      'snr': -4.75,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-aa555a0000100016',
#      'timestamp': 1880689953,
#      'time': '2020-12-17T14:51:31.401529Z',
#      'channel': 0,
#      'rssi': -110,
#      'snr': 4.25,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-fcc23dfffe0f8314',
#      'timestamp': 1529449692,
#      'time': '2020-12-17T14:51:31.419361Z',
#      'channel': 0,
#      'rssi': -110,
#      'snr': -10.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffef8021d',
#      'timestamp': 3280417860,
#      'time': '2020-12-17T14:51:31.415989Z',
#      'channel': 0,
#      'rssi': -108,
#      'snr': -6.5,
#      'rf_chain': 0,
#      'latitude': 51.49671,
#      'longitude': 5.31187,
#      'altitude': 16},
#     {'gtw_id': 'eui-0000024b080606ac',
#      'timestamp': 2472217380,
#      'time': '2020-12-17T14:51:31.401732Z',
#      'channel': 0,
#      'rssi': -110,
#      'snr': 7.2,
#      'rf_chain': 0,
#      'latitude': 52.0779,
#      'longitude': 4.3922,
#      'altitude': 7},
#     {'gtw_id': 'eui-fcc23dfffe0a682a',
#      'timestamp': 3666954324,
#      'time': '2020-12-17T14:51:31.406331Z',
#      'channel': 0,
#      'rssi': -119,
#      'snr': -10,
#      'rf_chain': 0,
#      'latitude': 52.0103,
#      'longitude': 7.6457,
#      'altitude': -1},
#     {'gtw_id': 'eui-a840411e96144150',
#      'timestamp': 106680492,
#      'time': '2020-12-17T14:51:31.413485Z',
#      'channel': 0,
#      'rssi': -122,
#      'snr': -5.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-7076ff00560502a7',
#      'timestamp': 1848214220,
#      'time': '',
#      'channel': 5,
#      'rssi': -110,
#      'snr': 1.5,
#      'rf_chain': 0,
#      'latitude': 51.916718,
#      'longitude': 4.245453,
#      'altitude': 22},
#     {'gtw_id': 'eui-a840411bda044150',
#      'timestamp': 2184743788,
#      'time': '2020-12-17T14:51:31.409766Z',
#      'channel': 0,
#      'rssi': -122,
#      'snr': -4.5,
#      'rf_chain': 0,
#      'latitude': 22.7,
#      'longitude': 114.24,
#      'altitude': 450},
#     {'gtw_id': 'eui-7276ff00390305a9',
#      'timestamp': 1040763220,
#      'time': '2020-12-17T14:51:31Z',
#      'channel': 5,
#      'rssi': -113,
#      'snr': -10.2,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-b827ebfffe4525a8',
#      'timestamp': 178795620,
#      'time': '2020-12-17T14:51:31.402026Z',
#      'channel': 0,
#      'rssi': -109,
#      'snr': -0.2,
#      'rf_chain': 0,
#      'latitude': 51.98675,
#      'longitude': 4.32076},
#     {'gtw_id': 'eui-a840411ece6c4150',
#      'timestamp': 2769750876,
#      'time': '2020-12-17T14:51:31.414308Z',
#      'channel': 0,
#      'rssi': -132,
#      'snr': -10.8,
#      'rf_chain': 0},
#     {'gtw_id': 'eui-a84041ffff1ee2c4',
#      'timestamp': 2361846556,
#      'time': '2012-01-01T14:58:52.389243Z',
#      'channel': 0,
#      'rssi': -129,
#      'snr': -9,
#      'rf_chain': 0,
#      'latitude': 51.190155,
#      'longitude': 6.389453,
#      'altitude': 450},
#     {'gtw_id': 'eui-aa555a0000100017',
#      'timestamp': 4084046821,
# ...
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 67,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T22:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.5224345,
#     'longitude': 23.160069}},
#   'metadata': {'time': '2020-12-18T07:56:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 164,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-06T20:30:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10650,
#     'latitude': 53.3389365,
#     'longitude': 22.3933095}},
#   'metadata': {'time': '2020-12-18T06:58:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10657,
#     'latitude': 53.5879695,
#     'longitude': 23.4418695}},
#   'metadata': {'time': '2020-12-18T08:17:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 67,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T22:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.5224345,
#     'longitude': 23.160069}},
#   'metadata': {'time': '2020-12-18T07:56:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 164,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-06T20:30:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 164,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-06T20:30:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.843556,
#     'longitude': 24.5559645}},
#   'metadata': {'time': '2020-12-18T09:28:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10650,
#     'latitude': 53.3389365,
#     'longitude': 22.3933095}},
#   'metadata': {'time': '2020-12-18T06:58:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 67,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T22:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10489,
#     'latitude': 51.8709525,
#     'longitude': 4.076277}},
#   'metadata': {'time': '2020-12-17T14:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 164,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-06T20:30:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.843556,
#     'longitude': 24.5559645}},
#   'metadata': {'time': '2020-12-18T09:28:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10650,
#     'latitude': 53.3389365,
#     'longitude': 22.3933095}},
#   'metadata': {'time': '2020-12-18T06:58:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 67,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T22:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10489,
#     'latitude': 51.8709525,
#     'longitude': 4.076277}},
#   'metadata': {'time': '2020-12-17T14:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10657,
#     'latitude': 53.5879695,
#     'longitude': 23.4418695}},
#   'metadata': {'time': '2020-12-18T08:17:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10663,
#     'latitude': 53.450346,
#     'longitude': 22.8651615}},
#   'metadata': {'time': '2020-12-18T07:35:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10489,
#     'latitude': 51.8709525,
#     'longitude': 4.076277}},
#   'metadata': {'time': '2020-12-17T14:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10650,
#     'latitude': 53.3389365,
#     'longitude': 22.3933095}},
#   'metadata': {'time': '2020-12-18T06:58:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.843556,
#     'longitude': 24.5559645}},
#   'metadata': {'time': '2020-12-18T09:28:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 875,
#     'latitude': 52.008576,
#     'longitude': 1.5400725}},
#   'metadata': {'time': '2020-12-17T12:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10657,
#     'latitude': 53.5879695,
#     'longitude': 23.4418695}},
#   'metadata': {'time': '2020-12-18T08:17:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10663,
#     'latitude': 53.450346,
#     'longitude': 22.8651615}},
#   'metadata': {'time': '2020-12-18T07:35:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10489,
#     'latitude': 51.8709525,
#     'longitude': 4.076277}},
#   'metadata': {'time': '2020-12-17T14:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10650,
#     'latitude': 53.3389365,
#     'longitude': 22.3933095}},
#   'metadata': {'time': '2020-12-18T06:58:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 59,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-15T13:21:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.843556,
#     'longitude': 24.5559645}},
#   'metadata': {'time': '2020-12-18T09:28:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 0,
#     'latitude': 0.0,
#     'longitude': 0.0}},
#   'metadata': {'time': '2020-01-01T01:01:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10648,
#     'latitude': 53.7452535,
#     'longitude': 24.0841125}},
#   'metadata': {'time': '2020-12-18T09:00:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 57,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T21:51:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 67,
#     'latitude': 51.969255,
#     'longitude': 1.3696815}},
#   'metadata': {'time': '2020-12-01T22:27:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10656,
#     'latitude': 53.987733,
#     'longitude': 25.335831}},
#   'metadata': {'time': '2020-12-18T10:12:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10663,
#     'latitude': 53.450346,
#     'longitude': 22.8651615}},
#   'metadata': {'time': '2020-12-18T07:35:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.843556,
#     'longitude': 24.5559645}},
#   'metadata': {'time': '2020-12-18T09:28:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10673,
#     'latitude': 53.9156445,
#     'longitude': 24.929514}},
#   'metadata': {'time': '2020-12-18T09:49:01Z'}},
#  {'app_id': 'icss_lora_tracker',
#   'dev_id': 'icspace23',
#   'payload_fields': {'gps_2': {'altitude': 10670,
#     'latitude': 53.660058,
#     'longitude': 23.749884}},
#   'metadata': {'time': '2020-12-18T08:38:01Z'}},
#  ...]

# %%
from pymongo import MongoClient
import urllib.parse

# init mongo connection
username = urllib.parse.quote_plus('dbUser')
password = urllib.parse.quote_plus("PwBhv72bEOq4NGlI")
url = "mongodb+srv://{}:{}@cluster0.edygp.mongodb.net/test?retryWrites=true&w=majority".format(username, password)
client = MongoClient(url)

flight_data_collection = client["flight_data"]["all_flights"]

# %%
#flight_data_collection.insert_many(icspace23_list)
